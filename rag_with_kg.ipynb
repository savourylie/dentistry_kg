# %%
from langchain.chains import GraphCypherQAChain
from langchain_community.graphs import Neo4jGraph
from neo4j import GraphDatabase
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv, find_dotenv
from langchain_community.chat_models import ChatOllama
import json
from openai import OpenAI
import openai
from collections import defaultdict
import tiktoken

# openai.proxy = {"http": OPENAI_BASE_URL}

_ = load_dotenv(find_dotenv())
# load_dotenv()

NEO4J_URI = os.getenv('NEO4J_URI')
NEO4J_USERNAME = os.getenv('NEO4J_USERNAME')
NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD')
# OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
OPENAI_PROXY_KEY = os.getenv('OPENAI_API_KEY')
OPENAI_BASE_URL = os.getenv('OPENAI_BASE_URL')

graph = Neo4jGraph(
    url=NEO4J_URI, 
    username=NEO4J_USERNAME, 
    password=NEO4J_PASSWORD
)

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))



# def get_schema(tx):
#     schema = {"nodes": [], "relationships": []}

#     # Get node labels and properties
#     result = tx.run("CALL db.schema.nodeTypeProperties()")
#     node_properties = {}
#     for record in result:
#         labels = record["nodeLabels"]
#         property_name = record["propertyName"]
#         labels_tuple = tuple(labels)  # Convert labels list to a tuple to use it as a key
#         if labels_tuple not in node_properties:
#             node_properties[labels_tuple] = []
#         node_properties[labels_tuple].append(property_name)

#     for labels, properties in node_properties.items():
#         node = {
#             "labels": labels,
#             "properties": properties
#         }
#         schema["nodes"].append(node)

#     # Get relationship types and properties
#     result = tx.run("CALL db.schema.relTypeProperties()")
#     rel_properties = {}
#     for record in result:
#         rel_type = record["relType"]
#         property_name = record["propertyName"]
#         if rel_type not in rel_properties:
#             rel_properties[rel_type] = []
#         rel_properties[rel_type].append(property_name)

#     for rel_type, properties in rel_properties.items():
#         relationship = {
#             "type": rel_type,
#             "properties": properties
#         }
#         schema["relationships"].append(relationship)

#     return schema

# with driver.session() as session:
#     schema = session.read_transaction(get_schema)

def get_schema(driver):
    schema = {
        "nodes": {
            "labels": [],
            "properties": defaultdict(lambda: defaultdict(set))
        },
        "relationships": {
            "types": [],
            "properties": defaultdict(lambda: defaultdict(set))
        }
    }

    with driver.session() as session:
        # Get node labels and properties
        result = session.run("""
        CALL db.schema.nodeTypeProperties()
        YIELD nodeLabels, propertyName
        RETURN nodeLabels, propertyName
        """)
        for record in result:
            for label in record['nodeLabels']:
                if label not in schema['nodes']['labels']:
                    schema['nodes']['labels'].append(label)
                schema['nodes']['properties'][label][record['propertyName']]

        # Get relationship types and properties
        result = session.run("""
        CALL db.schema.relTypeProperties()
        YIELD relType, propertyName
        RETURN relType, propertyName
        """)
        for record in result:
            rel_type = record['relType']
            if rel_type not in schema['relationships']['types']:
                schema['relationships']['types'].append(rel_type)
            schema['relationships']['properties'][rel_type][record['propertyName']]

        # Get unique property values for nodes
        for label in schema['nodes']['labels']:
            for prop in schema['nodes']['properties'][label]:
                result = session.run(
                    "MATCH (n) WHERE any(label IN labels(n) WHERE label = $label) "
                    "RETURN DISTINCT n[$prop] AS value",
                    label=label, prop=prop
                )
                schema['nodes']['properties'][label][prop] = [record['value'] for record in result if record['value'] is not None]

        # Get unique property values for relationships
        for rel_type in schema['relationships']['types']:
            for prop in schema['relationships']['properties'][rel_type]:
                result = session.run(
                    "MATCH ()-[r]->() WHERE type(r) = $rel_type "
                    "RETURN DISTINCT r[$prop] AS value",
                    rel_type=rel_type, prop=prop
                )
                schema['relationships']['properties'][rel_type][prop] = [record['value'] for record in result if record['value'] is not None]

    # Convert defaultdict to regular dict for JSON serialization
    schema['nodes']['properties'] = dict(schema['nodes']['properties'])
    schema['relationships']['properties'] = dict(schema['relationships']['properties'])
    for label in schema['nodes']['properties']:
        schema['nodes']['properties'][label] = dict(schema['nodes']['properties'][label])
    for rel_type in schema['relationships']['properties']:
        schema['relationships']['properties'][rel_type] = dict(schema['relationships']['properties'][rel_type])

    return schema

# Assuming you have already initialized the driver as mentioned
# driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

schema = get_schema(driver)

# Print the schema as formatted JSON
print(json.dumps(schema, indent=4, ensure_ascii=False))
# Out:
# {
#     "nodes": {
#         "labels": [
#             "Subject",
#             "Object"
#         ],
#         "properties": {
#             "Subject": {
#                 "name": [
#                     "骨性关节炎",
#                     "急性胰腺炎",
#                     "乙型肝炎",
#                     "感染性心内膜炎",
#                     "稳定型缺血性心脏疾病",
#                     "广泛性焦虑症",
#                     "原发性高血压",
#                     "口咽癌",
#                     "急性_TIN",
#                     "尤因肉瘤",
#                     "失眠症",
#                     "慢性胰腺炎",
#                     "肾盂和输尿管移行细胞癌",
#                     "弯刀综合征",
#                     "先天性卵巢发育不全综合征",
#                     "前列腺癌",
#                     "急性髓性白血病",
#                     "缺血性卒中",
#                     "B系急性淋巴细胞白血病",
#                     "生长激素缺乏症",
#                     "脑炎",
#                     "膝关节骨性关节炎",
#                     "类癌综合征",
#                     "下丘脑疾病",
#                     "B族链球菌感染",
#                     "狂犬病",
#                     "SMA",
#                     "食管癌",
#                     "单支冠状动脉",
#                     "消化性溃疡病",
#                     "荨麻疹或血管神经性水肿",
#                     "真菌性脑膜炎",
#                     "癫痫持续状态",
#                     "登革热",
#                     "室间隔缺损",
#                     "三尖瓣闭锁",
#                     "新生儿高血糖",
#                     "感觉障碍",
#                     "颅内肿瘤",
#                     "心力衰竭",
#                     "白内障",
#                     "垂体功能减退",
#                     "磨牙症",
#                     "喉癌",
#                     "MCTD",
#                     "多发性骨髓瘤",
#                     "肾母细胞瘤",
#                     "药物性肾损害",
#                     "痛风",
#                     "转移性乳腺癌",
#                     "子痫",
#                     "肠套叠",
#                     "子宫内膜癌",
#                     "主动脉弓异常",
#                     "胆汁性急性胰腺炎",
#                     "麻风病",
#                     "营养性巨幼细胞性贫血",
#                     "非小细胞肺癌",
#                     "抗中性粒细胞胞浆抗体ANCA",
#                     "非ST段抬高型心肌梗死",
#                     "皮肤鳞状细胞癌",
#                     "转移性骨肿瘤",
#                     "溃疡性结肠炎",
#                     "慢性肾病",
#                     "肾小管性酸中毒",
#                     "产后抑郁症",
#                     "西尼罗河病毒",
#                     "肥厚型心肌病",
#                     "流行性腮腺炎",
#                     "腹主动脉瘤",
#                     "ALL",
#                     "口腔黏膜炎",
#                     "心房扑动",
#                     "急性咽喉炎",
#                     "结节型多动脉炎",
#                     "持续性抑郁症",
#                     "高渗性脱水",
#                     "巴贝虫病",
#                     "急性阑尾炎",
#                     "肝硬化",
#                     "输尿管重复畸形",
#                     "类脂性肺炎",
#                     "少菌型_PB_麻风",
#                     "前置胎盘",
#                     "恶性间皮瘤",
#                     "类风湿关节炎",
#                     "病毒性咽炎",
#                     "破伤风",
#                     "玻璃体出血",
#                     "中耳炎",
#                     "胆囊炎",
#                     "急性膀胱炎",
#                     "小儿呼吸心搏骤停",
#                     "局部皮肤感染",
#                     "儿童NHL",
#                     "获得性或成人型_PAP",
#                     "慢性再障",
#                     "肺结核",
#                     "肾小球肾炎",
#                     "广泛性焦虑障碍",
#                     "膀胱癌",
#                     "致腹泻大肠埃希菌",
#                     "肠梗阻",
#                     "阿尔茨海默病",
#                     "腺病毒肺炎",
#                     "细菌性脑膜炎",
#                     "伴有骨病者",
#                     "真菌性肠炎",
#                     "肛门直肠鳞状细胞癌",
#                     "川崎病",
#                     "慢性阻塞性肺疾病",
#                     "小儿哮喘",
#                     "脓毒性休克",
#                     "先天性甲低",
#                     "无症状性低血糖",
#                     "早产",
#                     "小肠结肠炎",
#                     "疟疾",
#                     "溶血性贫血",
#                     "成人哮喘",
#                     "不全性Kartagener综合征",
#                     "典型RS",
#                     "糖原贮积症",
#                     "煤炭开采",
#                     "视网膜母细胞瘤血管网织细胞瘤多发性神经纤维瘤",
#                     "急性枕骨大孔疝",
#                     "海绵状血管瘤",
#                     "疑似IBD患儿",
#                     "EBV感染",
#                     "血吸虫病",
#                     "滑膜肉瘤",
#                     "弥漫性毒性甲状腺肿",
#                     "酒精性肝病",
#                     "唇腭裂",
#                     "GERD",
#                     "CrigerNajjar综合征",
#                     "病毒性脑炎",
#                     "咬指甲",
#                     "APSGN",
#                     "慢性稳定型心绞痛患者",
#                     "浆膜炎",
#                     "尘肺",
#                     "病毒性脑膜炎",
#                     "HPV感染",
#                     "维生素K缺乏症",
#                     "脑脓肿",
#                     "HS",
#                     "脊膜膨出和脊髓脊膜膨出",
#                     "急性_A_型_链球菌_GAS_咽炎",
#                     "ST段抬高型心肌梗死",
#                     "化脓性胃炎",
#                     "肾病综合征",
#                     "新生儿窒息",
#                     "脓胸",
#                     "FNS",
#                     "肠道病毒性咽炎",
#                     "三体综合征",
#                     "SLE",
#                     "胆红素脑病",
#                     "新生儿出血症",
#                     "HD",
#                     "Bartter综合征",
#                     "肾血管性高血压",
#                     "急性非淋巴细胞白血病",
#                     "NHL",
#                     "脓毒症",
#                     "白喉",
#                     "扩张性心肌病",
#                     "脑膜炎症",
#                     "重型再障型",
#                     "普通感冒",
#                     "睾丸旁横纹肌肉瘤",
#                     "肾小球性酸中毒",
#                     "额叶脑脓肿",
#                     "食物中毒",
#                     "肺癌",
#                     "气管软化",
#                     "抗环瓜氨酸抗体ACCP",
#                     "维生素A缺乏症",
#                     "GSD",
#                     "化脓性脑膜炎",
#                     "妊娠期高血压",
#                     "甲氨蝶呤治疗",
#                     "酒精性慢性胰腺炎",
#                     "脑膜炎",
#                     "HIV_感染",
#                     "疟疾感染",
#                     "恐怖症",
#                     "CVS",
#                     "胆管癌",
#                     "阿米巴病",
#                     "新生儿生理性黄疸",
#                     "心肌炎",
#                     "哮喘",
#                     "神经母细胞瘤",
#                     "先天性睾丸发育不全综合征",
#                     "中枢神经系统肿瘤",
#                     "念珠菌病",
#                     "急性肌炎",
#                     "羟化酶缺乏症",
#                     "金黄色葡萄球菌肠炎",
#                     "换血并发症",
#                     "窦性心动过缓",
#                     "蛲虫病",
#                     "扁桃体癌",
#                     "百日咳",
#                     "心肌梗死",
#                     "低钙血症和低镁血症",
#                     "钩虫病",
#                     "支气管肺炎",
#                     "肾前性",
#                     "非血管源性消化道出血",
#                     "自身免疫性溶血性贫血",
#                     "胱氨酸病",
#                     "甲状腺癌",
#                     "DiGeorge综合征",
#                     "乳腺原位癌",
#                     "婴儿猝死综合征",
#                     "骨髓细胞学检查",
#                     "贲门失弛缓",
#                     "血小板无力症",
#                     "先天性脑积水",
#                     "高血压急症",
#                     "永存动脉干",
#                     "放线菌病",
#                     "急性淋巴细胞白血病",
#                     "癫痫",
#                     "结核性脑膜炎",
#                     "HLH",
#                     "冷凝集素病",
#                     "肝癌",
#                     "肛门癌",
#                     "急性胆管炎",
#                     "帕金森病",
#                     "尿感",
#                     "Lowe眼脑肾综合征",
#                     "中毒患儿",
#                     "GSD型",
#                     "消化道梗阻",
#                     "颅内出血",
#                     "双糖不耐受",
#                     "系统性红斑狼疮",
#                     "侵入性念球菌病",
#                     "急性扁桃体炎",
#                     "胆石性胰腺炎",
#                     "肝性脑病",
#                     "慢性髓性白血病",
#                     "腮腺炎脑膜脑炎",
#                     "高钠血症",
#                     "阵发性缺氧发作",
#                     "吸入性皮质类固醇",
#                     "混合性高胆红素血症",
#                     "法四型右室双出口",
#                     "幽门螺杆菌感染",
#                     "惊厥",
#                     "新生儿黄疸",
#                     "未足月胎膜早破",
#                     "无创机械通气NIV",
#                     "消化性溃疡",
#                     "Fukuyama先天性肌营养不良",
#                     "慢性淋巴细胞白血病",
#                     "黏多糖病",
#                     "感染性食管炎",
#                     "HPS",
#                     "动脉导管未闭",
#                     "腮腺炎",
#                     "慢性腹泻",
#                     "婴儿_HIV感染",
#                     "尿崩症",
#                     "妊娠胆汁淤积",
#                     "肠病毒性脑膜炎",
#                     "先天性喉喘鸣",
#                     "儿童肥胖",
#                     "胰腺癌",
#                     "营养不良",
#                     "病理性反流",
#                     "慢性心房颤动",
#                     "新生儿缺氧缺血性脑病",
#                     "婴儿重症肌阵挛癫痫",
#                     "睾丸癌",
#                     "肠黏膜屏障功能障碍",
#                     "交通性脑积水",
#                     "CF患者",
#                     "致病性大肠杆菌肠炎",
#                     "CNS",
#                     "新发病",
#                     "寻常狼疮",
#                     "多关节型_JIA",
#                     "水杨酸盐",
#                     "铅中毒",
#                     "AHF",
#                     "小细胞肺癌",
#                     "AAA",
#                     "痔",
#                     "MFS",
#                     "幼年特发性关节炎",
#                     "HELLP_综合征",
#                     "新生儿化脑",
#                     "蚕豆病",
#                     "儿童偏头痛",
#                     "颅内压增高",
#                     "先天性肺囊肿",
#                     "继发感染",
#                     "早发GBS感染",
#                     "先天性二尖瓣狭窄",
#                     "麻疹感染",
#                     "IDA",
#                     "细菌性口炎",
#                     "过敏性紫癜",
#                     "新生儿低血糖症",
#                     "型糖尿病",
#                     "先天性肥厚性幽门狭窄",
#                     "婴儿肌纤维瘤",
#                     "secondary_drowning",
#                     "新生儿化脓性脑膜炎",
#                     "综合征型CNS表现",
#                     "急性中耳炎",
#                     "化脓性关节炎",
#                     "B_组链球菌肺炎",
#                     "注意缺陷多动障碍",
#                     "急性支气管炎",
#                     "急性运动轴索型神经病",
#                     "乳突炎",
#                     "脱水",
#                     "假丝酵母菌病",
#                     "BH缺乏症",
#                     "胎母输血",
#                     "新生儿筛查",
#                     "血管炎",
#                     "克罗恩病",
#                     "食物和呕吐物吸入",
#                     "自身免疫性肝炎",
#                     "房室间隔缺损",
#                     "新生儿输尿管巨大扩张",
#                     "感染性脑动静脉畸形",
#                     "支原体肺炎",
#                     "被犬咬伤者",
#                     "婴儿胃幽门括约肌",
#                     "DIC",
#                     "HCM",
#                     "一氧化碳中毒",
#                     "缺锌",
#                     "霍奇金病",
#                     "急性感染性喉炎",
#                     "青记",
#                     "声门上型喉癌",
#                     "胃炎",
#                     "横纹肌肉瘤",
#                     "早期先天性梅毒",
#                     "泌尿生殖系的横纹肌肉瘤",
#                     "梗阻性休克",
#                     "肺动脉瓣狭窄",
#                     "MAS",
#                     "卵形疟",
#                     "晚发型母乳性黄疸",
#                     "出生后感染性肺炎",
#                     "早产儿贫血",
#                     "婴幼儿脑积水",
#                     "化脑",
#                     "毛细胞白血病",
#                     "基底细胞癌",
#                     "慢性心肌炎",
#                     "汞中毒",
#                     "水痘",
#                     "生理性黄疸",
#                     "肺炎链球菌脑膜炎",
#                     "胆道蛔虫",
#                     "处方药或非处方药",
#                     "早发型B族链球菌感染",
#                     "新生儿胎粪栓塞综合征",
#                     "肺炎",
#                     "新生儿溶血病",
#                     "结节性硬化症",
#                     "垂体卒中",
#                     "植物性支气管炎",
#                     "多关节型类风湿因子阴性",
#                     "急性肾损伤",
#                     "畸形足",
#                     "新生儿颅内出血",
#                     "肾细胞癌",
#                     "低氧性呼吸衰竭和PPHN",
#                     "触电者",
#                     "蛔虫性阑尾炎",
#                     "部分性肺静脉异位连接",
#                     "左冠状动脉异常",
#                     "蛛网膜下腔出血",
#                     "病毒性心肌炎",
#                     "本病",
#                     "流感病毒肺炎",
#                     "RS",
#                     "重症渗出性多形红斑",
#                     "幕上硬膜下出血",
#                     "伯氨喹",
#                     "吸虫病",
#                     "进行性肌营养不良",
#                     "糖尿病",
#                     "气胸",
#                     "成骨肉瘤",
#                     "右下叶肺炎",
#                     "新生儿败血症",
#                     "先天性肠闭锁",
#                     "小儿特发性血小板减少性紫癜",
#                     "少关节型关节炎",
#                     "血友病甲乙",
#                     "肺吸虫病",
#                     "过敏性口炎",
#                     "曲霉菌脑膜炎",
#                     "狼疮肾炎",
#                     "多发性硬化症",
#                     "病毒性脑炎或脑膜脑炎",
#                     "宫颈癌",
#                     "金黄色葡萄球菌肺炎",
#                     "脑瘫",
#                     "变应原特异性免疫治疗",
#                     "恶性肿瘤",
#                     "JAS",
#                     "缺铁性贫血",
#                     "偶发痛风",
#                     "重型RS",
#                     "风疹病毒",
#                     "共济失调型",
#                     "泌尿道感染",
#                     "大动脉转位伴左室流出道梗阻",
#                     "佝偻病",
#                     "脱屑性间质性肺炎",
#                     "尿浓缩功能减退",
#                     "隐球菌病",
#                     "新生儿肝炎",
#                     "轮状病毒性肠炎",
#                     "神经源性膀胱",
#                     "迟发性运动障碍",
#                     "特发性生长激素缺乏症",
#                     "先天性巨结肠",
#                     "成人细菌性脑膜炎",
#                     "支气管肿瘤",
#                     "新生儿硬肿症",
#                     "短暂性抽动障碍",
#                     "地中海贫血",
#                     "消化道出血",
#                     "HUS",
#                     "RDS恢复期患儿",
#                     "代谢性碱中毒",
#                     "原发性硬化性胆管炎",
#                     "胱氨酸尿症",
#                     "皮肤紫癜",
#                     "足月儿RDS",
#                     "淋病和衣原体检测",
#                     "肺炎改变",
#                     "毒蛇咬伤",
#                     "ACS",
#                     "慢性TIN",
#                     "新生儿狼疮综合征",
#                     "CMV感染",
#                     "缺铁",
#                     "暴发型流脑",
#                     "肾小球性血尿",
#                     "葡萄球菌肺炎",
#                     "获得性失语性癫痫",
#                     "巨噬细胞活化综合征",
#                     "苯丙酮尿症",
#                     "平滑肌肉瘤",
#                     "卵巢癌",
#                     "Wilson病",
#                     "幼年型皮肌炎",
#                     "吉兰巴雷综合征",
#                     "尿道下裂",
#                     "儿童慢性型ITP",
#                     "完全性大动脉换位合并室间隔缺损及肺动脉狭窄",
#                     "急性会厌炎",
#                     "急腹泻",
#                     "法洛四联症",
#                     "诺如病毒肠炎",
#                     "PN_associated_cholestasis",
#                     "融合肾",
#                     "GSD型Tarui病肌磷酸果糖激酶缺陷",
#                     "低钾血症",
#                     "鹦鹉热衣原体肺炎",
#                     "无菌性脑膜炎",
#                     "支气管哮喘",
#                     "疣状癌",
#                     "脑积水",
#                     "Turner综合征",
#                     "阵发性剧烈腹痛",
#                     "进行性脊髓性肌萎缩症",
#                     "室上性心动过速",
#                     "儿童哮喘",
#                     "高血钾型肾小管酸中毒",
#                     "DSS或DHF",
#                     "复发进展型_MS",
#                     "先天性甲状腺功能减退症",
#                     "室上速",
#                     "重度佝偻病",
#                     "吸收不良",
#                     "黄色瘤或黄斑瘤",
#                     "肝细胞癌变",
#                     "腺癌",
#                     "严重感染性休克合并MOF",
#                     "骶髂关节炎",
#                     "中肠扭转",
#                     "原发性膀胱输尿管反流",
#                     "膀胱或前列腺横纹肌肉瘤",
#                     "室性心动过速",
#                     "觉醒性异态睡眠",
#                     "冠状动脉病变",
#                     "肺动脉狭窄",
#                     "再生障碍性贫血",
#                     "近端肾小管中毒二型",
#                     "低白蛋白血症",
#                     "毛细支气管炎",
#                     "肾脏异位",
#                     "心室颤动",
#                     "ICP",
#                     "呼吸衰竭",
#                     "意识障碍",
#                     "儿童IgAN",
#                     "叶酸",
#                     "急性白血病",
#                     "假性痛风性关节炎",
#                     "伴主动脉下室间隔缺损的右室双出口",
#                     "婴儿型",
#                     "良性痔出血",
#                     "急性低碳酸血症",
#                     "前壁心肌梗死",
#                     "艾滋病",
#                     "小儿消化性溃疡",
#                     "高凝状态",
#                     "儿童言语和语言障碍",
#                     "双侧肺发育不全或不发育",
#                     "脓气胸",
#                     "NB",
#                     "维生素B缺乏",
#                     "脐炎",
#                     "脑出血",
#                     "急性胃炎",
#                     "十二指肠炎",
#                     "急性肾上腺皮质功能衰竭",
#                     "SSPE",
#                     "强直型",
#                     "急性喉气管支气管炎",
#                     "代谢性疾病",
#                     "消化性溃疡出血",
#                     "IBD",
#                     "房间隔缺损",
#                     "淹溺后产生严重神经系统损伤",
#                     "系统性硬化症",
#                     "QT间期延长综合征",
#                     "原发性梗阻性巨输尿管",
#                     "PPHN",
#                     "HCMV引起的传染性单核细胞增多症",
#                     "血管源性消化道出血",
#                     "干性胸膜炎",
#                     "肠黏膜缺血",
#                     "WD",
#                     "慢性_TIN",
#                     "CD",
#                     "良性家族性新生儿惊厥",
#                     "LGMD患者",
#                     "急性肾炎",
#                     "全身过敏症状",
#                     "ADV肺炎",
#                     "反流性肾病",
#                     "黏多糖病型",
#                     "葡萄簇样肉瘤",
#                     "大面积烧伤",
#                     "疱疹性口炎",
#                     "原发肿瘤",
#                     "EH",
#                     "急性期",
#                     "唐氏综合征",
#                     "Wegener_肉芽肿",
#                     "不稳定型心绞痛",
#                     "甲基丙二酸血症",
#                     "颅外感染",
#                     "功能性消化不良",
#                     "慢性ITP",
#                     "低钠血症及低钾血症",
#                     "B细胞型非霍奇金淋巴瘤",
#                     "头颅血肿和帽状腱膜下出血",
#                     "颅咽管瘤",
#                     "急进性肾小球肾炎",
#                     "NTDs",
#                     "基因诊断",
#                     "腹泻",
#                     "双胎",
#                     "新生儿破伤风",
#                     "成人中重度哮喘",
#                     "梦魇",
#                     "肺静脉异位连接",
#                     "性早熟",
#                     "不典型川崎病",
#                     "生理性贫血",
#                     "未分化癌",
#                     "慢性气道炎症",
#                     "蛔虫病",
#                     "后尿道瓣膜症",
#                     "爽身粉吸入",
#                     "过敏性紫癜肾炎",
#                     "排泄性静脉尿路造影",
#                     "尿路感染",
#                     "重型",
#                     "脑血管畸形",
#                     "淹溺",
#                     "松果体区肿瘤",
#                     "恶性间叶瘤",
#                     "vWF抗体",
#                     "马蹄肾",
#                     "小儿慢性胃炎",
#                     "肌萎缩侧索硬化",
#                     "B族链球菌菌尿症",
#                     "维生素D缺乏性佝偻病",
#                     "小儿脑积水",
#                     "环性心境障碍",
#                     "重症急性胰腺炎",
#                     "急性中毒",
#                     "阻塞性脑积水",
#                     "HIV疾病",
#                     "NEC",
#                     "红细胞遗传代谢病",
#                     "恶心和或呕吐",
#                     "胃癌",
#                     "MillerFisher综合征",
#                     "先天性膈疝",
#                     "残余肿瘤",
#                     "双胎输血综合征",
#                     "严重低钠血症",
#                     "消化系统疾病",
#                     "中枢性尿崩症",
#                     "小脑幕切迹疝",
#                     "CKD",
#                     "蛔虫性腹膜炎",
#                     "难治性_SE",
#                     "生长发育",
#                     "肛瘘",
#                     "结节型基底细胞癌",
#                     "维生素A缺乏",
#                     "生长激素缺乏",
#                     "强迫性障碍",
#                     "炎症反应",
#                     "血尿",
#                     "生殖细胞性肿瘤",
#                     "脑瘤",
#                     "成人特发性高钙尿",
#                     "单纯腭裂",
#                     "全身性感染",
#                     "非肾小球性血尿",
#                     "铅脑病",
#                     "上感",
#                     "紧张性头痛",
#                     "腹泻病",
#                     "幼年型慢性粒单核细胞白血病",
#                     "重症肺炎",
#                     "卡氏肺孢子虫肺炎",
#                     "急性心绞痛",
#                     "锌缺乏",
#                     "甲状腺功能减退",
#                     "分离性焦虑症",
#                     "新生儿后期贫血",
#                     "年长儿泌尿道感染",
#                     "结节病",
#                     "膀胱充盈",
#                     "毛细淋巴管瘤",
#                     "脑炎型狂犬病",
#                     "GER",
#                     "手足口病合并中枢神经系统损害的重症病例",
#                     "范可尼综合征",
#                     "厌氧菌肺炎",
#                     "甲亢",
#                     "急性TIN",
#                     "原发性肾病综合征",
#                     "恶性贫血",
#                     "无脑畸形",
#                     "PKU",
#                     "绒毛膜羊膜炎",
#                     "B族溶血性链球菌GBS",
#                     "颅内感染性疾病",
#                     "甲状腺肿大",
#                     "行为抑制",
#                     "FSHD",
#                     "弥散性血管内凝血",
#                     "窦性心律失常",
#                     "巨输尿管",
#                     "MP肺炎",
#                     "念珠菌感染",
#                     "肾盂肾炎",
#                     "排尿性膀胱尿道造影",
#                     "慢性胃炎",
#                     "Santavuori肌营养不良",
#                     "血栓形成",
#                     "早产儿脑白质损伤",
#                     "垂体瘤",
#                     "SIDS",
#                     "爱唐综合征",
#                     "间质性肾炎",
#                     "急性上呼吸道感染",
#                     "肾上腺皮质激素治疗",
#                     "继发性巨输尿管",
#                     "急性铍中毒",
#                     "非心绞痛胸痛",
#                     "Laminin链缺乏型CMD",
#                     "肺脓肿",
#                     "念珠菌肺炎",
#                     "霍纳Horner综合征",
#                     "胆总管结石和胆管狭窄",
#                     "抗生素相关性腹泻",
#                     "梅毒",
#                     "土拉菌病",
#                     "小儿甲亢",
#                     "半侧面部肢体发育不良",
#                     "倒Y型输尿管重复畸形",
#                     "念珠菌性脑膜炎",
#                     "儿童IgA肾病",
#                     "隐球菌性脑膜炎",
#                     "沙眼衣原体肺炎",
#                     "近端肾小管酸中毒",
#                     "气道异物",
#                     "急性感染后肾小球肾炎",
#                     "隐匿性细菌性肺炎",
#                     "MGUS",
#                     "Q热",
#                     "热损伤",
#                     "进展性核硬化性白内障",
#                     "急性痔血栓",
#                     "巨幼红细胞性贫血",
#                     "肺炎链球菌肺炎",
#                     "慢性者",
#                     "肠易激综合征",
#                     "L型菌肺炎",
#                     "人工瓣膜心内膜炎",
#                     "弥散性LCH",
#                     "单处病损少菌型麻风患者",
#                     "皮肤黏膜型",
#                     "偏瘫型偏头痛",
#                     "缺血性脑卒中",
#                     "冠状动脉瘤",
#                     "晚期鳞癌_NSCLC",
#                     "喉部异物",
#                     "BMD患者",
#                     "活产儿",
#                     "血管瘤",
#                     "食管腺癌",
#                     "肾上腺功能不全",
#                     "单纯型膨出",
#                     "右室双出口",
#                     "先天畸形",
#                     "肾小管间质性肾炎",
#                     "梦呓",
#                     "髓鞘化障碍",
#                     "酸碱失衡",
#                     "偏头痛",
#                     "假膜性小肠结肠炎",
#                     "HIV感染",
#                     "TBMN",
#                     "新生儿内脏出血",
#                     "硬脑膜下积液",
#                     "出血性疾病",
#                     "免疫系统缺陷",
#                     "呼吸道白喉",
#                     "低血容量性休克",
#                     "肥厚性心肌病",
#                     "EB_病毒",
#                     "ARDS",
#                     "放射性结肠炎",
#                     "创伤后应激障碍",
#                     "迟发性喘息哮喘",
#                     "梗阻性巨输尿管",
#                     "脑血管意外",
#                     "GSD_O型",
#                     "下消化道出血",
#                     "流感病毒感染",
#                     "基底型偏头痛",
#                     "肝豆状核变性",
#                     "NETs",
#                     "二尖瓣狭窄",
#                     "假性痛风",
#                     "新生儿低血糖",
#                     "脑型放线菌病",
#                     "气管狭窄",
#                     "弥漫性淋巴管瘤",
#                     "特发性高钙尿症",
#                     "HSPN",
#                     "炎症性肠病",
#                     "肠旋转不良",
#                     "GBS感染",
#                     "其他病毒所致脑炎或脑膜炎",
#                     "UFH",
#                     "腺泡型横纹肌肉瘤",
#                     "GBS",
#                     "晚期血吸虫病",
#                     "重症失盐型",
#                     "急性非淋巴细胞白血病ANLL",
#                     "多发神经纤维瘤",
#                     "咳嗽变异性哮喘",
#                     "急性维生素A过多症",
#                     "急性妊娠期脂肪肝",
#                     "隐性脊柱裂",
#                     "银屑病性关节炎",
#                     "中间型和重型地中海贫血",
#                     "GSD型McArdle综合征",
#                     "先天感染",
#                     "ICH",
#                     "儿童发热",
#                     "周围肺动脉狭窄",
#                     "ALF",
#                     "放射性黏膜炎",
#                     "甲状腺肿",
#                     "JIA",
#                     "腹水",
#                     "小儿脑性瘫痪",
#                     "婴儿暂时性糖尿病",
#                     "免疫缺陷病",
#                     "感染性休克",
#                     "脊髓脊膜膨出",
#                     "右位心",
#                     "食管闭锁和食管气管瘘",
#                     "纤维蛋白生成障碍",
#                     "儿童",
#                     "立克次体感染"
#                 ],
#                 "type": [
#                     "疾病",
#                     "其他",
#                     "检查",
#                     "药物",
#                     "症状",
#                     "部位",
#                     "社会学",
#                     "其他治疗"
#                 ]
#             },
#             "Object": {
#                 "name": [
#                     "高热和出血性皮疹",
#                     "化脓性链球菌咽炎",
#                     "浓缩红细胞",
#                     "踝关节和腕关节",
#                     "早期_ERCP",
#                     "HBsAg阳性的人性交时如果对方未接种疫苗或无自然免疫应采取防护不应与他人共用牙刷或剃须刀应遮盖开放的割伤和擦伤使用漂白剂或洗涤剂清洁溢出血液不献血不捐献器官或精液",
#                     "葡萄球菌",
#                     "受体阻滞剂",
#                     "高强度他汀类药物治疗",
#                     "社交性焦虑",
#                     "适量的咖啡因摄入量",
#                     "舌根软腭腭扁桃体窝和腭弓咽外侧壁及咽后壁",
#                     "细菌钩端螺旋体分枝杆菌CMV病毒Hanta病毒以及多瘤病毒等",
#                     "放射治疗",
#                     "唑吡坦缓释剂和艾司佐匹克隆",
#                     "恶心和呕吐",
#                     "血尿",
#                     "右肺静脉与下腔静脉相连",
#                     "染色体核型分析",
#                     "尿急症状",
#                     "急性淋巴细胞白血病",
#                     "MRI",
#                     "TB两大系列",
#                     "GH水平的测定",
#                     "局灶性神经功能障碍",
#                     "膝内翻和膝外翻",
#                     "支气管类癌",
#                     "呼吸困难",
#                     "尿崩症",
#                     "青霉素",
#                     "蝙蝠咬伤或接触史",
#                     "脊柱侧弯",
#                     "吞咽困难",
#                     "心肌缺血症状或猝死",
#                     "消化道出血消瘦饱腹感腹部可触及肿块或肿大淋巴结黄疸进行性吞咽困难反复呕吐癌症家族史或者岁出现症状",
#                     "抗组胺药物和钙剂",
#                     "特异性血清学检查",
#                     "咪达唑仑",
#                     "血清白蛋白水平",
#                     "利尿剂",
#                     "胸部_X线",
#                     "轻度短暂_小时高血糖",
#                     "麻木感",
#                     "胸部X线片",
#                     "总体视力下降",
#                     "皮质类固醇",
#                     "磨牙习惯",
#                     "声带发育不良",
#                     "骨痛和贫血症状",
#                     "放线菌素D长春新碱和阿霉素",
#                     "肠易激综合征",
#                     "磺胺结晶",
#                     "别嘌呤醇",
#                     "体重减轻",
#                     "癫痫发作和痉挛",
#                     "内镜检查",
#                     "血浆置换",
#                     "岁以内",
#                     "阴道出血",
#                     "血管环",
#                     "ERCP",
#                     "银屑病",
#                     "亚叶酸钙",
#                     "支气管内超声波检查法和内镜超声",
#                     "抗蛋白酶PR抗体",
#                     "心脏生物标志物水平升高",
#                     "瘢痕形成",
#                     "各种实验室检查",
#                     "双能X线吸收仪DXA扫描",
#                     "糖尿病肾病",
#                     "阴离子间隙正常的高氯性代谢性酸中毒",
#                     "入院时和产后分娩后第一年",
#                     "脑膜炎",
#                     "室间隔酒精消融",
#                     "_岁的儿童",
#                     "身高增长",
#                     "Burkitt淋巴瘤",
#                     "右侧口腔黏膜发红",
#                     "地高辛",
#                     "头孢菌素",
#                     "明确或可疑已知传播媒介接触史",
#                     "乙型肝炎病毒",
#                     "药物治疗",
#                     "剧烈口渴高热烦躁不安肌张力增高",
#                     "溶血",
#                     "头孢西丁",
#                     "双能X线骨密度吸收仪",
#                     "依维莫司加曲妥珠单抗和紫杉醇",
#                     "腹痛恶心及呕吐",
#                     "慢性间质性肺炎",
#                     "未定类麻风_I极性结核样型麻风_TT_和界线类偏结核样麻风_BT",
#                     "中枢神经系统功能异常",
#                     "窥器检查",
#                     "咀嚼烟草和槟榔",
#                     "肺脑",
#                     "Sarilumab",
#                     "宫腔镜及内膜活检术",
#                     "EB病毒单核细胞增多症",
#                     "破伤风类毒素",
#                     "外伤或糖尿病控制不佳",
#                     "主动脉瓣下梗阻舒张功能障碍或心肌缺血",
#                     "广谱抗生素",
#                     "化疗",
#                     "发热",
#                     "静脉推注氟尿嘧啶",
#                     "性生活后排尿",
#                     "上气道阻塞",
#                     "男性",
#                     "维持和补充充足的水分和针对DHF和DSS的补液疗法",
#                     "皮疹",
#                     "早前B细胞肿瘤",
#                     "社会隔离感",
#                     "弥漫性羽毛状浸润",
#                     "莨菪浸膏片",
#                     "HIV_感染者",
#                     "伊曲康唑",
#                     "传统的紧急开放式修复术",
#                     "焦虑症状",
#                     "颈部侧位X光检查",
#                     "膀胱镜检查",
#                     "胸痛",
#                     "黏附集聚性大肠埃希菌",
#                     "肠外营养",
#                     "ApoE",
#                     "眼部检查",
#                     "甲硝唑",
#                     "PPI",
#                     "腰椎穿刺术脑脊液检查",
#                     "维生素D制剂",
#                     "异烟肼和利福平",
#                     "超声检查",
#                     "岁以下婴儿",
#                     "男性同性恋者",
#                     "IVIG非敏感型KD",
#                     "MRCP诊断",
#                     "普洛萘尔",
#                     "胸部_CT",
#                     "缺血症状",
#                     "呼吸科检查室",
#                     "脏器低灌注",
#                     "实验室检査",
#                     "终末期肾病",
#                     "葡萄糖",
#                     "左上腹痛",
#                     "多种生化检测",
#                     "巨结肠",
#                     "女性Hb血红蛋白gdL",
#                     "疟原虫",
#                     "红细胞内和红细胞外",
#                     "流感疫苗接种",
#                     "咳嗽咳痰和咯血",
#                     "房间隔缺损",
#                     "高烧频繁呕吐惊厥和意识障碍昏睡或昏迷",
#                     "肝糖原贮积症",
#                     "矽肺和煤工患尘肺",
#                     "腹腔神经丛阻滞术",
#                     "常染色体显性遗传性肿瘤",
#                     "剧烈头痛反复呕吐突然昏迷双瞳孔先变小后变大呼吸慢不规则或出现呼吸暂停血压上升脉搏变快",
#                     "四肢躯干",
#                     "痰培养",
#                     "持续的中上腹和脐周剧烈腹痛呕吐",
#                     "中等强度他汀类药物",
#                     "食管胃十二指肠镜和结肠镜检查",
#                     "遗传性免疫缺陷",
#                     "青霉素治疗",
#                     "磁共振成像",
#                     "直接抗球蛋白试验",
#                     "预防剂量的吡喹酮",
#                     "肿瘤附近的肌群或做截肢",
#                     "肝内胆管癌",
#                     "伤口感染",
#                     "吸入性肺炎",
#                     "葡萄糖醛酸转移酶部分或全部缺乏",
#                     "美金刚",
#                     "视乳头水肿",
#                     "MRI检查",
#                     "心脏杂音",
#                     "癫痫发作",
#                     "学龄期儿童",
#                     "剖宫产手术",
#                     "皮下免疫疗法SCIT和舌下免疫疗法SLIT",
#                     "皮肤病灶或咽部拭子细菌培养",
#                     "抑郁症状",
#                     "PETCT_检查",
#                     "血流储备分数_FFRCT_和_FFRMRI_检查",
#                     "胸膜炎及心包炎",
#                     "铍淋巴细胞增殖试验",
#                     "胰岛素耐量试验",
#                     "钙剂和维生素_D",
#                     "洗手",
#                     "基底细胞癌",
#                     "肿瘤致病因素",
#                     "凝血障碍",
#                     "青壮年",
#                     "其他有球形红细胞的溶血性贫血病症",
#                     "早期手术治疗",
#                     "_岁的儿童和青少年",
#                     "临时起搏器",
#                     "冠状动脉CT血管造影",
#                     "胃肠减压",
#                     "CSF_革兰氏染色",
#                     "过去__年内更换性伴侣",
#                     "T淋巴细胞异常",
#                     "难产高位产钳臀位胎头吸引不顺利产程中麻醉药镇痛药及催产药使用不当",
#                     "高热不退呼吸困难加重患侧呼吸运动受限语颤减弱叩诊呈浊音听诊呼吸音减弱管状呼吸音胸部叩诊积液上方呈鼓音听诊呼吸音减弱或消失",
#                     "肾上腺皮质激素",
#                     "夏秋两季",
#                     "第肋骨",
#                     "外周血细胞染色体核型分析",
#                     "遗传因素",
#                     "坐立不安或神经质易疲劳注意力难以集中易激惹肌肉紧张或睡眠障碍",
#                     "核黄疸",
#                     "维生素K",
#                     "钡剂造影",
#                     "体检",
#                     "空腹血糖测定",
#                     "微创青光眼手术",
#                     "原发性醛固酮增多症",
#                     "伐普坦类药物",
#                     "高血压",
#                     "糖尿病",
#                     "形态学分型",
#                     "ALL",
#                     "微生物血培养",
#                     "Td_疫苗",
#                     "肝功能检验",
#                     "心输出量减少液体潴留及血管收缩活性增加",
#                     "寒战出汗烦躁不安吞咽和呼吸困难恶心和呕吐",
#                     "既往有痛风史",
#                     "脑电图",
#                     "头痛畏光颈项强直",
#                     "急性再障",
#                     "腰椎穿刺",
#                     "慢性阻塞性肺疾病",
#                     "年龄大于岁黑人和有前列腺癌的家族史",
#                     "儿童阴囊肿瘤",
#                     "肾脏疾病史",
#                     "微需氧葡萄球菌厌氧菌和肠杆菌",
#                     "女性比男性更容易发病",
#                     "乳酸林格液或生理盐水溶液",
#                     "X射线或CT检查",
#                     "胃食管静脉曲张",
#                     "晚期肾病",
#                     "保守疗法",
#                     "流鼻涕和喉咙痛",
#                     "多门控捕获扫描_MUGA",
#                     "名JIA患儿中只有名ACCP为阳性",
#                     "手部",
#                     "长期动物性食物摄入不足",
#                     "生化异常",
#                     "地高辛水平",
#                     "血培养",
#                     "头痛",
#                     "四氢叶酸钙",
#                     "超声心动图",
#                     "颈部腺体触痛扁桃体肿胀或有分泌物无咳嗽体温大于C_F年龄岁以下",
#                     "心血管疾病",
#                     "大剂量的青霉素",
#                     "血清_HIV_快速检测",
#                     "疟原虫血涂片检测",
#                     "死亡率超过_",
#                     "行为干预",
#                     "Kras_基因突变",
#                     "尿急",
#                     "补液",
#                     "腺癌",
#                     "小关节关节炎",
#                     "溶组织阿米巴原虫",
#                     "血清胆红素峰值",
#                     "心包增厚或炎症",
#                     "运动性哮喘",
#                     "吸烟和饮酒",
#                     "OPEC__OPAC",
#                     "血清CA",
#                     "十一酸睾酮",
#                     "普瑞巴林",
#                     "曾发作胆道疼痛",
#                     "间隙性头痛学习成绩下降易疲劳及性格改变",
#                     "两性霉素B",
#                     "腓肠肌和比目鱼肌",
#                     "万古霉素加庆大霉素",
#                     "典型的单纯男性化型失盐型和非典型迟发型或轻型",
#                     "大量广谱抗生素",
#                     "低体温",
#                     "窦房结冲动发放缓慢",
#                     "枸橼酸哌嗪",
#                     "脑炎型狂犬病躁狂型",
#                     "放疗",
#                     "抗精神病药物",
#                     "肝硬化",
#                     "甲氧嘧啶磺胺甲基异恶唑",
#                     "尿常规和尿培养检查",
#                     "抗心肌M受体抗体",
#                     "手足震颤舞蹈病样不随意运动易受刺激烦躁不安严重者可发生惊厥",
#                     "高剂量马法兰后自体干细胞移植",
#                     "粪便直接涂片法",
#                     "发热咳嗽呼吸急促",
#                     "呕吐腹泻和胃肠减压等胃肠道液体大量丢失大面积烧伤手术或创伤出血等",
#                     "对乙酰氨基酚",
#                     "抑酸药",
#                     "天",
#                     "家族性发生倾向",
#                     "级",
#                     "_淀粉样蛋白诱发脑细胞损伤",
#                     "血清肌酐",
#                     "泼尼松龙",
#                     "肾活体组织检查",
#                     "甲状腺球蛋白测定",
#                     "多重连接探针扩增_MLPA和微阵列比较基因组杂交技术aCGH",
#                     "大肠杆菌",
#                     "芳香化酶抑制剂",
#                     "与婴儿同屋但不同床睡",
#                     "地西泮直肠给药",
#                     "膀胱癌或炎症性肠病",
#                     "曲妥珠单抗emtansine",
#                     "不建议常规做",
#                     "食管鳞癌和腺癌",
#                     "期待疗法",
#                     "营养补充剂",
#                     "皮肤瘀点瘀斑鼻出血牙龈出血月经过多血尿胃肠道出血",
#                     "非交通性脑积水",
#                     "胸部CT检查",
#                     "眼底检查",
#                     "主动脉弓异常",
#                     "农民及野外作业者",
#                     "骨髓活检",
#                     "遗传因素脑内致痫性损伤因素诱发性因素",
#                     "脑脊液压力增高",
#                     "产前超声",
#                     "胺碘酮",
#                     "耳鼻喉科和听力学家",
#                     "DEX_VP针剂_CsA",
#                     "肺炎支原体EB病毒感染",
#                     "骨转移",
#                     "外周关节炎强直性脊柱炎和不能区别的脊椎关节病",
#                     "近端球囊引导导管或大口径远端导管联合支架取栓器",
#                     "低钠血症",
#                     "_年生存率",
#                     "发热寒战黄疸和腹痛",
#                     "先天性心脏病",
#                     "细菌性感染如猩红热葡萄球菌引起的皮肤症状中毒性休克风湿热洛基山斑疹热和细螺旋体病",
#                     "运动迟缓强直静止性震颤和或姿势不稳",
#                     "肾脏及脑部的变化",
#                     "触痛性肝肿大和右侧胸腔积液",
#                     "刺激性呛咳呼吸困难发绀肺水肿及呼吸节律不整",
#                     "胰腺功能检查",
#                     "肝脏",
#                     "类风湿关节炎",
#                     "先天畸形",
#                     "出血性脑血管病或出血性卒中",
#                     "不含乳糖代乳品或去乳糖配方奶粉",
#                     "抗核抗体ANA特别是抗dsDNA和抗Sm抗体阳性",
#                     "中性粒细胞减少",
#                     "下颌角淋巴结肿大",
#                     "广泛多音调的喘鸣音",
#                     "岁以上的白人女性",
#                     "PY受体抑制剂和阿司匹林",
#                     "意识模糊有情绪变化",
#                     "柳氮磺胺吡啶及美沙拉嗪",
#                     "脑积水",
#                     "吸入性皮质类固醇",
#                     "腹水",
#                     "密切接触者近期死亡或患病换新工作或学校或者最后期限即将到来",
#                     "脑水肿抽搐甚至死亡",
#                     "心电图",
#                     "心肌梗塞代谢紊乱败血症和胃肠道疾病",
#                     "婴儿",
#                     "轻度至中度持续性哮喘和使用高剂量吸入性皮质类固醇的儿童生长",
#                     "自杀风险评估",
#                     "感染",
#                     "二代或三代头孢菌素",
#                     "INRPTT纤维蛋白原和纤维蛋白原降解产物检测",
#                     "光动力治疗",
#                     "青紫表现",
#                     "铋盐阿莫西林甲硝唑他咪唑呋喃唑酮呋喃妥因及庆大霉素",
#                     "电解质测试",
#                     "微量营养元素缺乏",
#                     "颈部肿块活检显示鳞状细胞癌",
#                     "血清学检查",
#                     "发热咳嗽呼吸急促的症状",
#                     "缺氧缺血性脑损伤",
#                     "经皮胆红素检测仪",
#                     "硝嗪试验",
#                     "压舌板检查",
#                     "简易认知状态评估量表_MiniCog",
#                     "气管插管和气管切开引起的并发症",
#                     "阿米替林",
#                     "淋巴结活检",
#                     "垂体瘤手术",
#                     "米索前列醇",
#                     "日本",
#                     "delp",
#                     "遗传性疾病",
#                     "睡眠卫生不佳",
#                     "CT_检查",
#                     "荧光原位杂交FISH",
#                     "室间隔酒精消融术_ASA",
#                     "免疫功能低下患者",
#                     "病史与体格检查",
#                     "排尿困难",
#                     "滑液尿酸单钠呈阴性",
#                     "疫苗接种",
#                     "幽门环肌切开术",
#                     "腹部绞痛",
#                     "总生存率",
#                     "呼吸急促及肋间隙凹陷",
#                     "ASA",
#                     "依维莫司和舒尼替尼",
#                     "脑膜脑炎",
#                     "苯巴比妥",
#                     "叶酸吸收",
#                     "病毒抗体检査",
#                     "抗利尿激素分泌或释放不足",
#                     "局部涂抹霜和润肤剂",
#                     "结肠切除术",
#                     "血脂",
#                     "神经系统后遗症",
#                     "面具脸",
#                     "意识模糊进行性低血压急性气促以及即将心脏停搏",
#                     "肺癌",
#                     "泳池和池塘的使用",
#                     "钙及维生素D",
#                     "组织病理学检查",
#                     "PCRSSCP分析",
#                     "阿米巴滋养体",
#                     "多吃少动学习压力增大心理负担加重等社会心理因素",
#                     "膦甲酸",
#                     "局部晚期不可切除肿瘤",
#                     "血糖血胆固醇水平下降",
#                     "胃食管反流病GERD",
#                     "心悸气短乏力胸痛头晕",
#                     "单纯性血尿和或蛋白尿",
#                     "胸部X线检查",
#                     "氯吡格雷",
#                     "_受体激动剂",
#                     "兴奋易激惹肌张力正常拥抱反射活跃吸吮反射正常呼吸平稳无惊厥",
#                     "双氯芬酸",
#                     "SCNA",
#                     "CA",
#                     "DonathLandsteiner_抗体",
#                     "网状内皮来源",
#                     "左旋门冬酰胺酶",
#                     "酒精",
#                     "CEBPANPMFLTITD的点突变",
#                     "硬质电视动态喉内镜检查",
#                     "妊娠期_B族链球菌菌尿症",
#                     "多菌型_MB_麻风",
#                     "普通肝素",
#                     "肋骨",
#                     "感染性休克",
#                     "间接喉镜",
#                     "高龄女性和医学共病",
#                     "脑室系统与蛛网膜下腔畅通",
#                     "持续咳嗽",
#                     "细菌性痢疾",
#                     "阳性家族史",
#                     "中度脱水",
#                     "门静脉肝动脉",
#                     "临床症状明显而多变病程多不超过个月血压低压差小肝增大肺有时有啰音",
#                     "麻风病",
#                     "口腔活动障碍",
#                     "碳酸氢钠",
#                     "心肺检查",
#                     "含铅涂料和受其污染的土壤和粉尘",
#                     "压力和焦虑",
#                     "凝血酶原时间",
#                     "阻塞性肺炎缺氧",
#                     "脂蛋白升高",
#                     "全身惊厥性_SE_或非惊厥性_SE",
#                     "嗜睡",
#                     "指检及发光肛镜或外部光源辅助肛镜检查",
#                     "脱髓鞘改变",
#                     "血小板计数升高",
#                     "宫颈环扎术",
#                     "长效受体激动剂",
#                     "睡眠卫生教育",
#                     "SLEMCTD血管炎综合征过敏性紫癜川崎病",
#                     "头痛上腹痛恶心",
#                     "阿司匹林",
#                     "尿液镜检分析",
#                     "B群链球菌GBS",
#                     "急性溶血性贫血",
#                     "肝肾综合征",
#                     "胸部_X_线_CXR",
#                     "恶心呕吐畏光和高声恐怖",
#                     "颅神经麻痹",
#                     "骨痛",
#                     "间歇口服治疗",
#                     "血沉和C反应蛋白",
#                     "结核性脑膜炎",
#                     "外伤性",
#                     "听诊气流不畅",
#                     "绝对便秘",
#                     "伊伐布雷定",
#                     "多囊肺",
#                     "ICU",
#                     "失血性贫血",
#                     "链球菌和葡萄球菌",
#                     "急性撕裂样腹痛",
#                     "心搏停止",
#                     "年轻的绝经前女性患者",
#                     "喹硫平",
#                     "胰胆管状况",
#                     "空气或液体钡剂灌肠",
#                     "适当抗生素",
#                     "惊厥嗜睡昏迷前囟隆起",
#                     "二代头孢菌素或喹诺酮和甲硝唑联合用药",
#                     "呼吸衰竭",
#                     "二尖瓣瓣叶增厚",
#                     "发疹第天发热消退皮疹及咳嗽持续约一周",
#                     "右心室发育极其不全甚至缺如",
#                     "血生化指标",
#                     "利多卡因",
#                     "皮肤紫癜",
#                     "流感疫苗",
#                     "肌肉紧张",
#                     "正常同年龄婴儿的最低血糖值",
#                     "微波ELISA",
#                     "血细胞比容为血小板计数为LLLDH为IUL天冬氨酸氨基转移酶AST为IUL丙氨酸氨基转移酶ALT为IUL",
#                     "进食减少恶心呕吐腹痛关节或肌肉疼痛皮肤黏膜干燥呼吸深长呼气中带有酮味脉搏细速血压下降体温不升甚至嗜睡淡漠昏迷",
#                     "胃食管反流",
#                     "阿糖胞苷__蒽环类药物例如柔红霉素或伊达比星",
#                     "乏力",
#                     "咯血盗汗和体重下降",
#                     "关节压痛计数关节肿胀计数健康评估问卷HAQ多维HAQMDHAQ疼痛患者和医生对病情的整体评估ESRCRP",
#                     "切除",
#                     "脑的发育",
#                     "关节的屈肌侧",
#                     "界线类偏结核样",
#                     "淡水淹溺的发作时间约为小时海水淹溺约为小时",
#                     "面色苍白反应欠佳少哭少动拒乳或吮乳减少呕吐和发热或体温不升",
#                     "腹泻",
#                     "所有先天性心脏病的",
#                     "抗核抗体",
#                     "心绞痛症状",
#                     "双角子宫",
#                     "肝活检",
#                     "阿尔及利亚安哥拉埃及尼日尔尼日利亚苏丹和撒哈拉以南的国家玻利维亚巴西哥伦比亚多明尼加共和国厄瓜多尔海地和巴拉圭阿富汗孟加拉国不丹缅甸柬埔寨中国印度印度尼西亚老挝马来西亚蒙古尼泊尔巴基斯坦巴布亚新几内亚菲律宾泰国和越南伊朗伊拉克沙特阿拉伯叙利亚土耳其和也门阿尔巴尼亚俄罗斯和前苏联其他国家",
#                     "弥漫性系膜硬化",
#                     "巨催乳素血症",
#                     "哥哥姐姐",
#                     "广泛的白细胞碎裂性小血管炎",
#                     "髋膝踝关节",
#                     "骨髓活组织检查",
#                     "宫内感染性肺炎",
#                     "高分辨超声检查",
#                     "粪胆原定量增加",
#                     "丙米嗪",
#                     "烦躁不安易怒等症状",
#                     "远端主动脉夹层",
#                     "肺炎",
#                     "腱反射亢进",
#                     "水肿红斑和压痛",
#                     "美国东部肿瘤协作组表现情况标准",
#                     "常规超声检查",
#                     "CK和CKMB水平",
#                     "精神运动性改变",
#                     "腹泻与呕吐丢失大量的水和电解质",
#                     "蛋白质能量营养不良",
#                     "真菌检査",
#                     "血管加压药",
#                     "虫草制剂",
#                     "BH负荷试验",
#                     "血小板计数L",
#                     "结肠镜检查",
#                     "最终唇裂修复术",
#                     "母血HbF定量测定",
#                     "脑炎",
#                     "血苯丙氨酸测定",
#                     "防晒措施",
#                     "血尿蛋白尿及高血压",
#                     "反复咳嗽",
#                     "肠壁水肿出血坏死或穿孔",
#                     "神经系统症状",
#                     "单纯疱疹病毒脑炎水痘流行性腮腺炎风疹肠道上呼吸道病毒感染",
#                     "体位性水肿颈静脉压升高肺底部捻发音",
#                     "胃十二指肠病变",
#                     "培美曲塞和顺铂联合治疗",
#                     "X线胸片",
#                     "组织学检查",
#                     "洛哌丁胺",
#                     "DTPHBVHIB",
#                     "心室发育不良",
#                     "输尿管造瘘",
#                     "颅内细菌性或真菌性动脉瘤",
#                     "全血细胞计数凝血肝肾功能血糖尿常规",
#                     "秋冬季",
#                     "心脏左向右分流",
#                     "单独手术或放疗",
#                     "狂犬疫苗",
#                     "幽门痉挛",
#                     "肝素",
#                     "KayserFleischer_环",
#                     "开窗通风或脱离中毒环境",
#                     "主胰管串珠样改变",
#                     "动物性腺发育不良",
#                     "胎盘早剥",
#                     "革兰氏阴性菌感染",
#                     "未接种疫苗未全程接种",
#                     "疱疹病毒巨细胞包涵体病毒EB病毒",
#                     "肝和肌肉",
#                     "胃肠道感染",
#                     "华法林",
#                     "喉梗阻",
#                     "异基因造血干细胞移植",
#                     "蓝绿色色斑",
#                     "硫酸镁",
#                     "非甾体抗炎药_NSAID_和饮酒",
#                     "鼻中裂和或唇中线裂",
#                     "导尿治疗",
#                     "神经系统检查完全正常且血压正常",
#                     "阑尾管腔的梗阻",
#                     "外科手术放疗和化疗",
#                     "皮肤苍白瘀斑或瘀点",
#                     "新型免疫调节药物例如干扰素疗法",
#                     "鞍鼻",
#                     "膀胱前列腺睾丸旁阴道子宫和外阴部",
#                     "A_或_B_子类",
#                     "门静脉栓塞",
#                     "新生儿贫血",
#                     "气胸心脏压塞肺栓塞和主动脉缩窄",
#                     "呼吸困难和乏力",
#                     "高频通气HFOV",
#                     "土拉菌病",
#                     "紫外线",
#                     "小头畸形",
#                     "淀粉酶测定",
#                     "热带中非和西非地区和西太平洋的一些岛屿",
#                     "血清淀粉酶",
#                     "血清胆红素",
#                     "TNF抑制剂",
#                     "病理性Q波形成",
#                     "支气管肺炎",
#                     "早产儿红细胞寿命天比足月儿天更短促红细胞生成素EPO水平低下由于早产儿发育未成熟生后前几周产生EPO的部位主要在肝脏而肝脏对缺氧的敏感性不如肾脏因此产生EPO较少早产儿生长迅速血液稀释疾病因素早产儿易患许多疾病加重贫血医源性失血早产儿病情重需取血做各种检查营养因素",
#                     "Tdap_疫苗",
#                     "SMA的发病机制",
#                     "号染色体短臂的等臂染色体",
#                     "神经肌肉阻滞",
#                     "头颅CT或MRI",
#                     "病毒感染",
#                     "高热头痛呕吐食欲缺乏及精神委靡",
#                     "腹部胀满感",
#                     "基底细胞样鳞癌",
#                     "颅内肿瘤",
#                     "个白细胞mm的浸润",
#                     "多奈哌齐",
#                     "酒精吸烟和家族史",
#                     "活性炭悬液或_NaHCO洗胃并口服牛奶或蛋清硫酸镁导泻",
#                     "阿昔洛韦",
#                     "广泛性足突融合或消失",
#                     "足月儿",
#                     "联合化疗",
#                     "尼卡地平",
#                     "不明原因的上腹痛无痛性梗阻性黄疸体重下降以及后背痛",
#                     "强效联合抗逆转录病毒治疗_ART",
#                     "疗程周",
#                     "CSF治疗性引流",
#                     "内镜疗法",
#                     "阵发性黑尿血红蛋白尿",
#                     "基因分型",
#                     "详细的体格检查和血常规分类计数",
#                     "动脉闭塞或狭窄",
#                     "腹痛",
#                     "失眠症",
#                     "闭角型青光眼",
#                     "睾丸扭转",
#                     "结膜充血",
#                     "产妇_B族链球菌定植",
#                     "性欲减退",
#                     "光动力疗法",
#                     "左半小结肠综合征",
#                     "血清电解质",
#                     "重症肺炎",
#                     "出血溃疡或结痂",
#                     "母婴血型不合",
#                     "外周血涂片",
#                     "面部血管纤维瘤",
#                     "剧烈头痛视力障碍或眼肌麻痹",
#                     "胸部_X_射线或胸部_CT检查",
#                     "重度高血压",
#                     "大环内酯类药物",
#                     "咳嗽败血性发热呼吸困难",
#                     "巨唾细胞活化综合征",
#                     "白细胞总数常增高中性粒细胞比例也增高",
#                     "肿胀和关节渗出",
#                     "外科矫正",
#                     "产伤",
#                     "腰肋疼痛",
#                     "瓣膜修复或置换术",
#                     "皮肤和黏膜苍白软弱无力心悸气急食欲差不愿活动精神不振对环境不感兴趣易烦躁哭闹肝脾淋巴结可轻度增大",
#                     "_至_",
#                     "吸烟",
#                     "舍曲林",
#                     "禁食禁水",
#                     "人工呼吸机的高通气",
#                     "HIV__型",
#                     "现场急救",
#                     "支气管内治疗和胸膜治疗",
#                     "氟康唑",
#                     "转移性右下腹痛",
#                     "肠梗阻消化道出血瘘管腹腔内及肛周腹腔脓肿及肠穿孔",
#                     "直接作用的口服抗病毒药物",
#                     "自身免疫因素",
#                     "右肺静脉与下腔静脉",
#                     "高频超声检查光学相干断层扫描以及共聚焦显微镜",
#                     "左冠状动脉重新植入主动脉或主动脉冠状动脉间搭桥",
# ...
#                     "间断性右上腹痛",
#                     "眼部变化",
#                     "急性肾小球肾炎",
#                     "完全性",
#                     "高强度的竞技运动",
#                     "头颅或全脑全脊髓照射",
#                     "腭裂颈部脊柱裂胸腔狭小上下肢比例失调胫骨和指缺如",
#                     "多普勒超声和腹部CT",
#                     "奥法木单抗",
#                     "母乳",
#                     "抗血小板药或抗凝血剂",
#                     "神经系统受损",
#                     "假性囊肿",
#                     "胰管减压术",
#                     "急性肠系膜腺炎",
#                     "脑脊液单纯疱疹病毒PCR检查",
#                     "颅内压急剧增高导致脑疝",
#                     "多巴酚丁胺",
#                     "视神经乳头水肿",
#                     "岁无症状学龄儿童人群",
#                     "呼吸肺活量测定法",
#                     "支气管镜活组织检查",
#                     "孕妇阴道GBS的带菌率为",
#                     "喘息气急偶尔有喘鸣",
#                     "结节性肝硬化",
#                     "胃肠反应",
#                     "急性中毒",
#                     "脑血管造影",
#                     "脑脓肿",
#                     "肌张力减低和拥抱反射异常",
#                     "X线交叉互补基因XRCC",
#                     "针吸细胞分析",
#                     "支持治疗和输血",
#                     "度",
#                     "社交性恐怖",
#                     "支气管囊肿",
#                     "子痫前期",
#                     "电生理绘图检查",
#                     "焦虑障碍和物质滥用",
#                     "内镜下睫状体冷凝术",
#                     "咽痛",
#                     "寂静肺",
#                     "皮肤受累",
#                     "培门冬酶",
#                     "西酞普兰",
#                     "ACT除青蒿琥酯加磺胺多辛乙胺嘧啶",
#                     "DTaP_疫苗",
#                     "高频性耳聋",
#                     "多脏器功能衰竭",
#                     "斑块破裂",
#                     "岁以内心率在次分以下岁在次分以下岁以上在次分以下",
#                     "弥漫性毛细血管内增生性肾小球肾炎",
#                     "血清降钙素",
#                     "营养不良或生长发育迟缓",
#                     "绝经后阴道出血",
#                     "PCR法",
#                     "食管气管支气管和肺",
#                     "核素锝扫描",
#                     "膀胱输尿管反流",
#                     "长效阿片类药物激动剂",
#                     "StevensJohnson综合征",
#                     "抗幽门螺杆菌治疗",
#                     "厌食",
#                     "红斑水疱",
#                     "深部脑刺激",
#                     "诺卡菌属马杜拉放线菌和链霉菌属中的一些种",
#                     "钙通道阻滞剂或长效硝酸酯",
#                     "烧伤样红斑性斑疹",
#                     "白斑黏膜白斑病及红斑黏膜红斑病",
#                     "吞咽困难和体重减轻",
#                     "肺栓塞",
#                     "PCR",
#                     "岁以内儿童",
#                     "流质饮食",
#                     "小婴儿或昏迷患者",
#                     "常染色体隐性遗传病",
#                     "血清钠和血渗透压上升",
#                     "塌陷型局灶性肾小球硬化",
#                     "室间隔破裂",
#                     "溶栓治疗",
#                     "多门电路探测扫描",
#                     "ReedSternberg细胞",
#                     "围产期感染",
#                     "正常垂体组织",
#                     "母亲使用大麻",
#                     "粪便聚合酶链反应_PCR_检查",
#                     "生长激素缺乏",
#                     "患SLE的母亲所生育的新生婴儿",
#                     "消化性溃疡",
#                     "电子显微镜检查",
#                     "腹部_CT_扫描",
#                     "结缔组织中胶原纤维数量不足和质的异常",
#                     "奥瑞珠单抗",
#                     "肾积水",
#                     "肺炎链球菌B型流感嗜血杆菌及脑膜炎奈瑟菌",
#                     "鼻病毒呼吸道合胞病毒流感病毒副流感病毒柯萨奇病毒埃可病毒腺病毒人类偏肺病毒冠状病毒",
#                     "持续导联心电图监测",
#                     "经颅多普勒超声",
#                     "血性腹泻",
#                     "粪便镜检",
#                     "肺部小转移或骨转移",
#                     "内科治疗",
#                     "GBS",
#                     "无痛性锁骨上颈部或其他部位淋巴结肿大",
#                     "高频震荡人工呼吸机HFOV",
#                     "真菌感染",
#                     "发热食欲减退恶心呕吐及中性粒细胞计数的升高",
#                     "后尿道瓣膜",
#                     "典型心绞痛特征",
#                     "轻度感觉丧失",
#                     "发热不适食欲缺乏和体重下降",
#                     "发热气喘发绀及肺部中小湿啰音及叩浊音",
#                     "颈部或脑干部交感神经受损伤",
#                     "雌激素经皮给药",
#                     "右上腹出现的腹膜炎",
#                     "腹部压痛僵硬防卫征反跳痛或肠鸣音减弱或消失",
#                     "血脂治疗",
#                     "上腹颈部下颌或手臂",
#                     "骨质疏松",
#                     "静脉滴注晶体液和胶体液",
#                     "肝酶升高",
#                     "瘙痒导致的皮肤抓痕和或轻度黄疸",
#                     "乙胺嘧啶",
#                     "超声标准",
#                     "齿轮样强直",
#                     "金黄色葡萄球菌肠炎",
#                     "皮肤或黏膜破损的分泌物直接涂片",
#                     "心内膜心肌活检EMB",
#                     "皮肤或睾丸肿块",
#                     "膜性白喉",
#                     "口服药",
#                     "日光和紫外线暴露史",
#                     "认知功能障碍伴急性记忆障碍精神和行为表现",
#                     "创伤烧伤或感染例如脓疱病导致的皮肤开放性损伤",
#                     "鞍区",
#                     "肾脏超声",
#                     "妊娠超过周",
#                     "咽培养",
#                     "肌肉无力",
#                     "双输尿管芽的顶端在进入后肾前融合成一根",
#                     "HIV感染",
#                     "两性霉素_B_联合氟胞嘧啶",
#                     "RET原癌基因种系突变",
#                     "头晕眼前发黑耳鸣",
#                     "粪便虫卵和寄生虫检查",
#                     "肉眼血尿",
#                     "培唑帕尼",
#                     "细菌性脑膜炎",
#                     "拉贝洛尔尼卡地平酚妥拉明肼屈嗪",
#                     "症状复发",
#                     "肠穿孔顽固性出血或中毒性巨结肠",
#                     "神经系统",
#                     "苯二氮卓类药物或抗精神病药物",
#                     "乳胶凝集试验",
#                     "膝髋手以及腰椎和颈椎",
#                     "终末期肝病",
#                     "病毒性脑膜炎",
#                     "鼻咽拭子",
#                     "双侧乳房切除术",
#                     "近端肾小管重吸HC收功能障碍",
#                     "那他珠单抗",
#                     "气急喘息胸闷或咳嗽",
#                     "低分子右旋糖酐",
#                     "系列超声检查",
#                     "岁以内小儿",
#                     "深色染发剂的使用吸烟饮酒",
#                     "稽留热",
#                     "心动过速呼吸过速发热和低血压轻微焦虑和意识模糊以及出汗伴有左肺呼吸音减弱",
#                     "精神状态失常",
#                     "肾盂肾炎膀胱炎尿道炎",
#                     "溶血性链球菌A组",
#                     "血氧饱和度测定",
#                     "膝髋手部小关节近指间关节与远指间关节脊椎特别是腰椎和颈椎",
#                     "MM_或相关疾病",
#                     "肝脾肿大",
#                     "烧伤烫伤",
#                     "持续性",
#                     "胃流出道梗阻",
#                     "血清黏度增加",
#                     "伤口清创",
#                     "骨髓穿刺和活检",
#                     "眼镜度数不够",
#                     "肛周痛",
#                     "奈多罗米",
#                     "血红蛋白尿",
#                     "西替利嗪加伪麻黄碱",
#                     "烦躁不安疲乏无力表情呆滞反应迟钝两眼直视食欲差嗜睡",
#                     "_mmHg",
#                     "九价_HPV_疫苗",
#                     "中耳炎",
#                     "FEV或FVC水平",
#                     "认知功能障碍",
#                     "血清或_CSF_N甲基D天门冬氨酸NMDA谷氨酸受体抗体",
#                     "粪便弹性蛋白酶",
#                     "百日咳博德特氏菌",
#                     "硫唑嘌呤单药治疗方案",
#                     "TSH_水平",
#                     "漱口水",
#                     "药物依赖性",
#                     "全身_CT",
#                     "化脓性并发症",
#                     "循环衰竭迹象",
#                     "慢性肾衰竭",
#                     "急性肾功能衰竭或高钾血症",
#                     "间歇性腹部不适",
#                     "肝掌和蜘蛛痣",
#                     "抗胆碱能药",
#                     "内漏移植物闭塞移植物移位伴主动脉颈扩张",
#                     "Durvalumab",
#                     "氨苄西林或头孢霉素类加大环内酯类",
#                     "_人年",
#                     "冠状动脉造影",
#                     "顽固性便秘",
#                     "B超或排泄性尿路造影IVU",
#                     "智能迟缓和脑性瘫痪的儿童",
#                     "学龄儿童",
#                     "尿液分析",
#                     "金黄色葡萄球菌",
#                     "弱激光治疗",
#                     "住院治疗",
#                     "胰腺损伤",
#                     "经食道超声心动图TOE",
#                     "大量抗生素",
#                     "持续周以上的不明原因关节肿胀",
#                     "血浆置换术",
#                     "流鼻涕鼻塞打喷嚏咽喉痛咳嗽头痛不适感发热",
#                     "吞咽困难构音障碍和共济失调",
#                     "ROM利福平氧氟沙星和米诺环素单剂化疗",
#                     "新生儿和小婴儿",
#                     "强化化疗方案",
#                     "颅脑影像学检査",
#                     "剖腹手术探查",
#                     "直接Coombs试验",
#                     "瘫痪肢体抽搐",
#                     "超声",
#                     "高蛋白低脂肪饮食",
#                     "SMN基因的纯合缺失",
#                     "血液培养全血细胞计数白细胞分类计数和血小板计数胸部X线检查腰椎穿刺",
#                     "磺胺类药物呋喃妥因和水杨酸盐",
#                     "发热呼吸困难和排痰性咳嗽",
#                     "大肠埃希菌",
#                     "的冠状动脉瘤可能持续年",
#                     "顺铂和吉西他滨",
#                     "剧烈呛咳憋气及发绀",
#                     "皮肤瘀点瘀斑",
#                     "恶性高热",
#                     "_____",
#                     "甲紫",
#                     "自发性阴道出血",
#                     "腹水胃食管静脉曲张和静脉曲张出血肝性脑病和或黄疸",
#                     "毛细血管瘤",
#                     "压迫或压榨性中心性胸痛",
#                     "胰腺炎家族史",
#                     "肥胖",
#                     "白甲症",
#                     "微创手术如胸腔镜手术",
#                     "长期药物治疗",
#                     "张大嘴巴伸展颌肌",
#                     "促胃肠动力药",
#                     "阑尾切除术",
#                     "葡萄糖钾及肾上腺皮质激素",
#                     "横行切口",
#                     "室间隔缺损",
#                     "钡餐造影",
#                     "急性肾衰竭",
#                     "最近在狂犬病流行国家被已知传播媒介抓伤或咬伤最近与蝙蝠接触职业或在娱乐活动中暴露",
#                     "阻塞性睡眠呼吸暂停综合征REM睡眠行为障碍夜惊",
#                     "婴幼儿神经系统疾病",
#                     "持续性脑电图监测",
#                     "妊娠期高血压",
#                     "围生期感染",
#                     "抗人球蛋白Coombs直接及间接试验",
#                     "胃镜检查与病理组织活体检查",
#                     "难辨梭状芽胞杆菌",
#                     "克霉唑",
#                     "红霉素或青霉素",
#                     "年龄",
#                     "饮食调节",
#                     "三氧化二砷暴露",
#                     "肛裂",
#                     "右颈部包块",
#                     "急性肾功能衰竭",
#                     "CT和或MRI头部扫描",
#                     "第__秒用力呼气量_FEV_和肺一氧化碳弥散能力_DLCO",
#                     "骨髓有核细胞中原始和幼稚淋巴细胞总和",
#                     "高热抽搐及呕吐",
#                     "核酸扩增试验",
#                     "第三常见的肿瘤",
#                     "肝动脉栓塞术",
#                     "爱唐EhlersDanlos综合征",
#                     "无病生存率和无结肠造口的生存率",
#                     "声嘶",
#                     "胸腺发育不良",
#                     "白喉抗毒素",
#                     "粪便或尿液镜检",
#                     "垂体后叶素西咪替丁氨基己酸",
#                     "_为男性_为女性",
#                     "自身免疫性肝炎",
#                     "持续低氧血症",
#                     "NSAIDs",
#                     "阿法替尼_afatinib",
#                     "纵膈淋巴结取样",
#                     "局灶性临床表现颅神经受累视乳头水肿及癫痫发作",
#                     "温水坐浴",
#                     "胸腔穿刺术",
#                     "黑人的发病率",
#                     "重症监护病房",
#                     "盆腔或腹部放射治疗",
#                     "HT再摄取抑制剂",
#                     "胆囊切除术",
#                     "副作用和如何识别急性胰腺炎发作",
#                     "FSMEIMMUN_Junior",
#                     "湿疹",
#                     "结节状或弥漫侵犯型",
#                     "Quick_Inventory_of_Depressive_Symptoms_QIDS",
#                     "多导睡眠图",
#                     "剧烈腹痛",
#                     "输尿管远端的功能性或机械性梗阻",
#                     "子痫",
#                     "硫唑嘌呤疗法",
#                     "糖原合成酶缺陷",
#                     "环戊丙酸酯",
#                     "钙通道阻滞剂",
#                     "胸部X线平片",
#                     "坏死性小肠结肠炎",
#                     "磷酸奥司他韦",
#                     "健康教育",
#                     "染色体异常的发生率",
#                     "抑郁症",
#                     "非甾体抗炎药",
#                     "上睑下垂",
#                     "特异性抗微生物治疗",
#                     "Wilson病",
#                     "替莫唑胺",
#                     "肾瘢痕",
#                     "谷胱甘肽还原酶缺乏",
#                     "脐动脉或静脉插管换血疗法红细胞增多症动脉导管开放低体温",
#                     "管型",
#                     "阵发性腹部绞痛",
#                     "室性心动过速",
#                     "三环类抗抑郁药例如丙米嗪或第二代抗精神病药物例如喹硫平",
#                     "腕关节和膝关节",
#                     "瘘管",
#                     "个月虚弱婴儿及未成熟儿",
#                     "感音神经性听力丧失",
#                     "万古霉素",
#                     "糖原和脂肪贮存不足",
#                     "大脑半球",
#                     "岁以下儿童",
#                     "全程血尿",
#                     "神经影像学检查",
#                     "快速抗原检测",
#                     "亚硝酸盐试纸条试验",
#                     "口腔卫生",
#                     "视野测试",
#                     "肾病综合征",
#                     "基本的实验室检查",
#                     "严重呼吸困难烦躁鼻扇口唇及面部发绀三凹征",
#                     "激素受体ER_和_PR和_HER_neu_状态",
#                     "胸片",
#                     "高选择性动脉造影",
#                     "婴儿与老年人",
#                     "中毒性巨结肠",
#                     "肌肉磷酸甘油变位酶缺陷",
#                     "膝踝肘腕等大关节肿痛",
#                     "沙门菌菌血症",
#                     "病因不明尿钙排出增多而血钙正常",
#                     "恩替诺特",
#                     "抗利尿激素缺乏",
#                     "病原菌",
#                     "精神检查",
#                     "免疫荧光检查",
#                     "脑水肿",
#                     "完全性肺静脉异位连接及部分性肺静脉异位连接",
#                     "头颅增大",
#                     "营养不良",
#                     "射频消融术",
#                     "紫绀",
#                     "肾动脉杂音",
#                     "输注红细胞新鲜冰冻血浆和血小板",
#                     "复苏氧疗及其他支持措施",
#                     "化学预防",
#                     "女性收缩压",
#                     "免疫紊乱",
#                     "Morrow手术",
#                     "甘露醇",
#                     "预后差",
#                     "非特异性的腹痛或背痛",
#                     "塞替派和多柔比星",
#                     "四肢和躯干",
#                     "抗生素治疗",
#                     "低丙种球蛋白血症",
#                     "肾穿刺活组织检查",
#                     "营养支持",
#                     "头昏头痛乏力四肢酸痛眩晕晕厥肌颤动视力模糊失眠嗜睡多汗肢端麻木耳鸣步态不稳",
#                     "氢化可的松",
#                     "呼气喘鸣",
#                     "白三烯受体拮抗剂",
#                     "EMB",
#                     "失蛋白性肠病",
#                     "造血干细胞移植",
#                     "儿童后期",
#                     "气道炎症和气道高反应",
#                     "高颅压",
#                     "甲泼尼龙冲击疗法",
#                     "大量饮酒",
#                     "_年生存率和复发风险",
#                     "皮损可无颜色或轻微着色或表现为红色粉色或瘢痕样白色",
#                     "脾脓肿",
#                     "转氨酶小于unitsL",
#                     "渐进式阻力训练",
#                     "先兆子痫",
#                     "初次病毒血症",
#                     "指趾炎",
#                     "尿激酶",
#                     "细胞介导性免疫受损",
#                     "输血和袪铁治疗",
#                     "干眼症",
#                     "大脑皮质的特异病征性扩散的血量减少",
#                     "血乳酸",
#                     "外周血异型淋巴细胞增多脑脊液蛋白增高和血清肝酶增高",
#                     "接触感染的患者年龄较轻冬季参加日托暴露于香烟烟雾或其他呼吸道刺激物",
#                     "中枢神经系统影像学检查",
#                     "听力图",
#                     "脚气病",
#                     "低热中热高热超高热",
#                     "手术治疗",
#                     "静脉注射免疫球蛋白IVIG",
#                     "口腔温度为_",
#                     "新生儿筛查",
#                     "实验室检查",
#                     "胸部X线",
#                     "对乙酰氨基酚和异烟肼",
#                     "月经量多痛性包块异常阴道分泌物肌瘤脱出",
#                     "早产儿尤其是极低出生体重儿输糖速率应_mgkg__min",
#                     "抗白血病化疗",
#                     "骨髓增生异常综合征",
#                     "非典型和典型抗精神病药物",
#                     "鼻溢和鼻塞",
#                     "中枢神经系统受累",
#                     "呼吸道病毒感染",
#                     "啰音颈静脉怒张S奔马律S和S重迭奔马律心包摩擦音外周灌注不足窦性心动过速房性和室性心律失常低血压感觉异常和淋巴结病",
#                     "放疗部位",
#                     "咳嗽和呼吸困难",
#                     "天四联疗法天序贯疗法或者天三联疗法",
#                     "舒马曲坦",
#                     "限钠饮食和利尿",
#                     "呼吸循环障碍",
#                     "早产低出生体重黑人多胎以及母亲高龄",
#                     "颅内其他非病毒性感染",
#                     "耳镜检查",
#                     "脊髓脑干以及外周和自主神经",
#                     "血清尿电泳",
#                     "吸入糖皮质激素",
#                     "东部肿瘤合作组ECOG功能状态评分",
#                     "血小板减少",
#                     "神经系统损害",
#                     "胰岛细胞功能发育不够成熟",
#                     "机体防御能力普遍或部分下降",
#                     "新生儿先天性免疫功能缺陷白血病肿瘤或化疗者",
#                     "支持性治疗",
#                     "HIV_检测阴性",
#                     "乳酸脱氢酶_LDH_检查",
#                     "双下肢瘫痪及大小便失禁",
#                     "饮食治疗",
#                     "房室连接不一致心室左襻",
#                     "因子异常或抗凝物质过多",
#                     "多巴胺激动剂",
#                     "酒精戒断预防治疗",
#                     "遗尿"
#                 ],
#                 "type": [
#                     "症状",
#                     "疾病",
#                     "其他治疗",
#                     "部位",
#                     "检查",
#                     "社会学",
#                     "药物",
#                     "流行病学",
#                     "手术治疗",
#                     "其他",
#                     "预后",
#                     "并发症",
#                     "药物治疗"
#                 ]
#             }
#         }
#     },
#     "relationships": {
#         "types": [
#             ":`Predicate`"
#         ],
#         "properties": {
#             ":`Predicate`": {
#                 "null": []
#             }
#         }
#     }
# }

# %%
# Convert schema to JSON
schema_json = json.dumps(schema, indent=4, ensure_ascii=False)
# print(schema_json)
# print(type(schema_json))
print(schema_json)
# Out:
# <class 'str'>
# {
#     "nodes": [
#         {
#             "labels": [
#                 "Subject"
#             ],
#             "properties": [
#                 "name",
#                 "type"
#             ]
#         },
#         {
#             "labels": [
#                 "Object"
#             ],
#             "properties": [
#                 "name",
#                 "type"
#             ]
#         }
#     ],
#     "relationships": [
#         {
#             "type": ":`Predicate`",
#             "properties": [
#                 null
#             ]
#         }
#     ]
# }

# %%
encoding = tiktoken.get_encoding("cl100k_base")
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
encoding.encode("tiktoken is great!")
# Out:
# [83, 1609, 5963, 374, 2294, 0]

# %%
len(encoding.encode(schema_json))
# Out:
# 99

# %%
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_tokens_from_string(schema_json, "gpt-3.5-turbo")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 num_tokens_from_string(schema_json, "gpt-3.5-turbo")
#
# Cell In[9], line 3, in num_tokens_from_string(string, encoding_name)
#       1 def num_tokens_from_string(string: str, encoding_name: str) -> int:
#       2     """Returns the number of tokens in a text string."""
# ----> 3     encoding = tiktoken.get_encoding(encoding_name)
#       4     num_tokens = len(encoding.encode(string))
#       5     return num_tokens
#
# File ~/Datamorph/kg_dentistry/venv/lib/python3.9/site-packages/tiktoken/registry.py:68, in get_encoding(encoding_name)
#      65     assert ENCODING_CONSTRUCTORS is not None
#      67 if encoding_name not in ENCODING_CONSTRUCTORS:
# ---> 68     raise ValueError(
#      69         f"Unknown encoding {encoding_name}. Plugins found: {_available_plugin_modules()}"
#      70     )
#      72 constructor = ENCODING_CONSTRUCTORS[encoding_name]
#      73 enc = Encoding(**constructor())
#
# ValueError: Unknown encoding gpt-3.5-turbo. Plugins found: ['tiktoken_ext.openai_public']

# %%
from langchain.prompts.prompt import PromptTemplate


CYPHER_GENERATION_TEMPLATE = """
任务: 生成Cypher语句以查询图数据库。
说明:
仅使用架构中提供的关系类型和属性。
不要使用任何其他未提供的关系类型或属性。
Schema:
{schema}

注意: 不要在回答中包含任何解释或道歉。
不要回答任何要求构建Cypher语句以外的问题。
除了生成的Cypher语句外，不要包含任何文本。

问题:
{question}"""

# CYPHER_GENERATION_TEMPLATE = """
# Task:Generate Cypher statement to query a graph database.
# Instructions:
# Use only the provided relationship types and properties in the schema.
# Do not use any other relationship types or properties that are not provided.
# Schema:
# {schema}
# Cypher examples:
# # How many streamers are from Norway?
# MATCH (s:Stream)-[:HAS_LANGUAGE]->(:Language {{name: 'no'}})
# RETURN count(s) AS streamers

# Note: Do not include any explanations or apologies in your responses.
# Do not respond to any questions that might ask anything else than for you to construct a Cypher statement.
# Do not include any text except the generated Cypher statement.

# The question is:
# {question}"""

CYPHER_GENERATION_PROMPT = PromptTemplate(
    input_variables=["schema", "question"], template=CYPHER_GENERATION_TEMPLATE
)

# chain_language_example = GraphCypherQAChain.from_llm(
#     ChatOllama(model="command-r-plus:104b-q2_K", temperature=0), graph=graph, verbose=True,
#     # ChatOpenAI(temperature=0), graph=graph, verbose=True,
#     cypher_prompt=CYPHER_GENERATION_PROMPT
# )

# llm = ChatOllama(model="command-r-plus:104b-q2_K", temperature=0)

llm = ChatOpenAI(
        model="gpt-4-turbo",
        temperature=0.3,
        api_key=OPENAI_PROXY_KEY,
        base_url=OPENAI_BASE_URL,
    )

print(llm)

# %%
prompt = "What are the benefits of using AI in healthcare?"
response = llm.predict(prompt)
print(response)

# %%
len(schema_json)

# %%
chain_language_example = GraphCypherQAChain.from_llm(
    llm, graph=graph, verbose=True,
    cypher_prompt=CYPHER_GENERATION_PROMPT
)

filled_prompt = CYPHER_GENERATION_PROMPT.format(schema=schema_json, question="失眠怎么办？")

chain_language_example.run(filled_prompt)

# %%
# 配置 OpenAI 服务  

client = OpenAI()

response = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "讲个笑话",
        }
    ],
    # model="gpt-3.5-turbo",
    model="gpt-4o",
)

print(response)
